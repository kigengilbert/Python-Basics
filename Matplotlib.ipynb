# %%
import matplotlib.pyplot as plt
from datetime import datetime as dt

# %%
x_values = list(range(1000))

# %%
squares = [x**2 for x in x_values]

# %%
plt.scatter(x_values,squares , c=squares,cmap=plt.cm.Blues , edgecolors='none',s=10)
plt.title('Square Numbers',fontsize=24)
plt.xlabel('Value', fontsize=18)
plt.ylabel('Square of Value', fontsize=18)
plt.tick_params(axis='both',which='major', labelsize=14)
plt.scatter(x_values[0],squares[0] , c='green' , edgecolors='none',s=100)
plt.scatter(x_values[-1],squares[-1] , c='red' , edgecolors='none',s=100)
plt.scatter(x_values[499],squares[499] , c='yellow' , edgecolors='none',s=100)
plt.savefig('squares.png', bbox_inches='tight')

# %%
plt.savefig('squares.png', bbox_inches='tight')

# %%
a_values = list(range(30))
a_squares= [a**2 for a in a_values]
a_cubes= [a**3 for a in a_values]

# %%
plt.scatter(a_values, a_squares,c='red',edgecolors='none',s=10)
plt.scatter(a_values, a_cubes,c='blue',edgecolors='none',s=10)
plt.xlabel('Values', fontsize=18)
plt.fill_between(a_values, a_cubes, a_squares, facecolor='yellow', alpha=0.25)

# %% [markdown]
# __Date manipulation__

# %%
today =dt.now()
date_string = dt.strftime(today,'%H:%M')
print(date_string)
# Out:
# 22:25
