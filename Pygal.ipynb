# %%
import pygal

# %%
x_values = [0,1,2,3,4,5]
x_squares = [0,1,4,9,16,25]

chart= pygal.Line()
chart.force_uri_protocol = 'http'
chart.add('x^2', x_squares)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# G:\conda\envs\ver3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# ...
